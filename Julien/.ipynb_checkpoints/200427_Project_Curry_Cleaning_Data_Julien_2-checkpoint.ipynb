# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# https://www.kaggle.com/jmmvutu/eda-online-c2c-fashion-store-user-behaviour
# https://www.kaggle.com/kerneler/starter-e-commerce-users-of-a-french-4b0f4745-8/notebook
df = pd.read_csv('../dataset.csv')

# %%
df.head()
# Out:
#         identifierHash  type     country language  socialNbFollowers  \
# 0 -7279641312655250028  user  Etats-Unis       en                  3
# 1 -1456013578740053406  user   Allemagne       de                  3
# 2  9006282053848196165  user       Suède       en                  3
# 3 -7154634866120535654  user     Turquie       en                  3
# 4  2858299215060733023  user      France       en                  3
#
#    socialNbFollows  socialProductsLiked  productsListed  productsSold  \
# 0                8                    0               0             0
# 1                8                    0               0             0
# 2                8                    0               0             0
# 3                8                    0               0             0
# 4                8                    0               0             0
#
#    productsPassRate  ...  civilityTitle  hasAnyApp hasAndroidApp  hasIosApp  \
# 0               0.0  ...            mrs      False         False      False
# 1               0.0  ...            mrs      False         False      False
# 2               0.0  ...             mr       True         False       True
# 3               0.0  ...            mrs      False         False      False
# 4               0.0  ...             mr       True         False       True
#
#   hasProfilePicture  daysSinceLastLogin  seniority  seniorityAsMonths  \
# 0              True                 709       3205             106.83
# 1              True                 709       3205             106.83
# 2              True                 689       3205             106.83
# 3              True                 709       3205             106.83
# 4              True                 709       3205             106.83
#
#    seniorityAsYears  countryCode
# 0               8.9           us
# 1               8.9           de
# 2               8.9           se
# 3               8.9           tr
# 4               8.9           fr
#
# [5 rows x 24 columns]

# %%
df[df['socialNbFollows']<8].describe()
# Note for Brian: There are 139 of 90k+ users who have ('socialNbFollows'<8). Only a very few outliers of those seem to be active users.
# => I think we could leave the subgroup out.
# Out:
#        identifierHash  socialNbFollowers  socialNbFollows  \
# count    1.390000e+02         139.000000       139.000000
# mean     4.470508e+17           8.424460         3.913669
# std      5.251901e+18          15.664498         2.964725
# min     -9.069299e+18           3.000000         0.000000
# 25%     -4.070444e+18           3.000000         0.000000
# 50%      6.331368e+17           4.000000         5.000000
# 75%      5.188139e+18           5.500000         7.000000
# max      9.101213e+18         121.000000         7.000000
#
#        socialProductsLiked  productsListed  productsSold  productsPassRate  \
# count           139.000000      139.000000    139.000000        139.000000
# mean             36.316547        1.366906      2.848921         12.266187
# std             144.086832        6.024279     12.296408         31.514104
# min               0.000000        0.000000      0.000000          0.000000
# 25%               0.000000        0.000000      0.000000          0.000000
# 50%               3.000000        0.000000      0.000000          0.000000
# 75%              14.000000        0.000000      1.000000          0.000000
# max            1140.000000       54.000000    108.000000        100.000000
#
#        productsWished  productsBought  civilityGenderId  daysSinceLastLogin  \
# count      139.000000      139.000000        139.000000          139.000000
# mean        19.359712        3.287770          1.755396          256.964029
# std         66.905082       13.522523          0.549594          252.938109
# min          0.000000        0.000000          1.000000           11.000000
# 25%          0.000000        0.000000          1.000000           23.500000
# 50%          0.000000        0.000000          2.000000          190.000000
# 75%          5.000000        1.000000          2.000000          506.500000
# max        531.000000      105.000000          3.000000          704.000000
#
#          seniority  seniorityAsMonths  seniorityAsYears
# count   139.000000         139.000000        139.000000
# mean   3078.532374         102.618058          8.551799
# std     164.922261           5.497286          0.458111
# min    2852.000000          95.070000          7.920000
# 25%    2858.000000          95.270000          7.940000
# 50%    3197.000000         106.570000          8.880000
# 75%    3201.000000         106.700000          8.890000
# max    3205.000000         106.830000          8.900000

# %%
# active users = prospective buyers or prospective sellers or active social users
# prospective buyers: those who interacting with products of others with a like/wishlist/purchase
# prospective sellers: those who are having at least one product for sale or listed
# active social users: those who are interacting with other users by following accounts (in the dataset the baseline socialNbFollows appears to be 8 and not 0)

df_active= df.loc[(df["productsListed"] !=0)|(df["productsSold"] !=0)|(df["productsWished"]!=0)|(df["productsBought"]!=0)|(df["socialProductsLiked"]!=0)|(df["socialNbFollows"]>8)]
df_active.shape
# Out:
# (22288, 24)

# %%
# Segmenting the users into 4 subgroups:
# 1. exclusive buyers: those who have bought at least 1 product but haven't sold anything
# 2. exclusive sellers: those who have sold at least 1 product but haven't bought anything
# 3. both buyers and sellers: those who have bought at least 1 product and sold at least 1 product
# 4. prospective users: those who haven't bought and sold anything but who are actively interacting with other accounts

# %%
# 1st Segment: exclusive buyers: those who have bought at least 1 product
df_exclusive_buyers = (df_active
                       .loc[(df['productsSold'] == 0) & (df['productsBought'] != 0)]
                       .assign(user_type='exclusive_buyer'))
df_exclusive_buyers.describe()
# The descibe function provides us with key information concerning this segment:
# 4857 active users are exclusive buyers who buy in average 2.5 products (Median=1, IQR= 2). => Most exclusive buyers are small buyers.
# Out:
#        identifierHash  socialNbFollowers  socialNbFollows  \
# count    4.857000e+03        4857.000000      4857.000000
# mean    -6.787677e+16           4.651637         8.928557
# std      5.312927e+18           3.600481         8.110722
# min     -9.219834e+18           3.000000         0.000000
# 25%     -4.595531e+18           3.000000         8.000000
# 50%     -5.360249e+16           4.000000         8.000000
# 75%      4.475140e+18           5.000000         8.000000
# max      9.221188e+18          57.000000       482.000000
#
#        socialProductsLiked  productsListed  productsSold  productsPassRate  \
# count          4857.000000     4857.000000        4857.0            4857.0
# mean             33.405806        0.051884           0.0               0.0
# std             269.345065        0.445767           0.0               0.0
# min               0.000000        0.000000           0.0               0.0
# 25%               0.000000        0.000000           0.0               0.0
# 50%               1.000000        0.000000           0.0               0.0
# 75%              12.000000        0.000000           0.0               0.0
# max           16040.000000       12.000000           0.0               0.0
#
#        productsWished  productsBought  civilityGenderId  daysSinceLastLogin  \
# count     4857.000000     4857.000000       4857.000000         4857.000000
# mean        15.280008        2.478896          1.729669          313.204653
# std         81.531676        4.577632          0.459670          272.887611
# min          0.000000        1.000000          1.000000           11.000000
# 25%          0.000000        1.000000          1.000000           31.000000
# 50%          0.000000        1.000000          2.000000          249.000000
# 75%          4.000000        2.000000          2.000000          628.000000
# max       2635.000000       93.000000          3.000000          709.000000
#
#          seniority  seniorityAsMonths  seniorityAsYears
# count  4857.000000        4857.000000       4857.000000
# mean   3068.391806         102.279638          8.523212
# std     167.251170           5.574870          0.464897
# min    2852.000000          95.070000          7.920000
# 25%    2857.000000          95.230000          7.940000
# 50%    3197.000000         106.570000          8.880000
# 75%    3201.000000         106.700000          8.890000
# max    3205.000000         106.830000          8.900000

# %%
# 2nd Segment: exclusive sellers: those who have bought at least 1 product
df_exclusive_sellers = (df_active
                        .loc[(df['productsSold'] != 0) & (df['productsBought'] == 0)]
                        .assign(user_type='exclusive_seller'))
df_exclusive_sellers.describe()
# The descibe function provides us with key information concerning this segment:
# 1474 active users are exclusive sellers who buy in average 5.6 products (Median=2, IQR=3). => Most exclusive sellers are small sellers.
# Out:
#        identifierHash  socialNbFollowers  socialNbFollows  \
# count    1.474000e+03        1474.000000      1474.000000
# mean     4.261365e+16          11.329715        29.096336
# std      5.324734e+18          26.642000       431.964384
# min     -9.221801e+18           3.000000         0.000000
# 25%     -4.534347e+18           4.000000         8.000000
# 50%      1.995009e+16           6.000000         8.000000
# 75%      4.568205e+18          10.000000         8.000000
# max      9.204738e+18         744.000000     13764.000000
#
#        socialProductsLiked  productsListed  productsSold  productsPassRate  \
# count          1474.000000     1474.000000   1474.000000       1474.000000
# mean             56.278155        3.609905      5.581411         37.834057
# std            1367.880067       12.060120     12.909017         44.462528
# min               0.000000        0.000000      1.000000          0.000000
# 25%               0.000000        0.000000      1.000000          0.000000
# 50%               1.000000        0.000000      2.000000          0.000000
# 75%               4.000000        3.000000      4.000000         90.000000
# max           51671.000000      217.000000    170.000000        100.000000
#
#        productsWished  productsBought  civilityGenderId  daysSinceLastLogin  \
# count     1474.000000          1474.0       1474.000000         1474.000000
# mean         3.849389             0.0          1.824966          230.961330
# std         56.764258             0.0          0.534512          238.738821
# min          0.000000             0.0          1.000000           11.000000
# 25%          0.000000             0.0          2.000000           17.000000
# 50%          0.000000             0.0          2.000000          125.000000
# 75%          0.000000             0.0          2.000000          418.000000
# max       1842.000000             0.0          3.000000          709.000000
#
#         seniority  seniorityAsMonths  seniorityAsYears
# count  1474.00000        1474.000000       1474.000000
# mean   3061.93555         102.064328          8.505488
# std     168.84189           5.627837          0.469363
# min    2852.00000          95.070000          7.920000
# 25%    2857.00000          95.230000          7.940000
# 50%    3196.00000         106.530000          8.880000
# 75%    3201.00000         106.700000          8.890000
# max    3205.00000         106.830000          8.900000

# %%
# 3rd Segment: both buyers and sellers: those who have bought at least 1 product and sold at least 1 product
df_buyers_sellers = (df_active
                     .loc[(df['productsSold'] != 0) & (df['productsBought'] != 0)]
                     .assign(user_type='buyer_and_seller'))
df_buyers_sellers.describe()
# The descibe function provides us with key information concerning this segment:
# 562 active users are both buyers and sellers with both higher average and mean values for the number of products sold and bought. 
# => This segment seems to be the most active and the platform: the behaviour of these users deserves to be looked into more thoroughly.
# Out:
#        identifierHash  socialNbFollowers  socialNbFollows  \
# count    5.620000e+02         562.000000       562.000000
# mean     3.286952e+17          13.209964        12.604982
# std      5.214071e+18          16.317987        23.445021
# min     -9.211565e+18           3.000000         0.000000
# 25%     -4.258622e+18           5.000000         8.000000
# 50%      7.869879e+17           8.000000         8.000000
# 75%      4.530167e+18          14.000000        10.000000
# max      9.187045e+18         147.000000       450.000000
#
#        socialProductsLiked  productsListed  productsSold  productsPassRate  \
# count           562.000000      562.000000    562.000000        562.000000
# mean            107.256228        4.927046      6.761566         43.736477
# std             407.349454       17.147364     15.329538         44.582841
# min               0.000000        0.000000      1.000000          0.000000
# 25%               3.000000        0.000000      1.000000          0.000000
# 50%              18.000000        1.000000      2.000000         40.800000
# 75%              74.750000        3.000000      6.000000         93.000000
# max            5979.000000      244.000000    174.000000        100.000000
#
#        productsWished  productsBought  civilityGenderId  daysSinceLastLogin  \
# count      562.000000      562.000000        562.000000          562.000000
# mean        56.179715        8.836299          1.832740           85.104982
# std        179.375481       25.523710          0.496472          147.735870
# min          0.000000        1.000000          1.000000           11.000000
# 25%          1.000000        1.000000          2.000000           11.000000
# 50%          5.000000        3.000000          2.000000           17.000000
# 75%         25.000000        7.000000          2.000000           67.750000
# max       1916.000000      405.000000          3.000000          696.000000
#
#          seniority  seniorityAsMonths  seniorityAsYears
# count   562.000000         562.000000        562.000000
# mean   3068.361210         102.278470          8.523167
# std     167.623175           5.587301          0.465811
# min    2852.000000          95.070000          7.920000
# 25%    2857.000000          95.230000          7.940000
# 50%    3197.000000         106.570000          8.880000
# 75%    3201.000000         106.700000          8.890000
# max    3205.000000         106.830000          8.900000

# %%
# 4th Segment: exclusive social users: those who haven't bought and sold anything but who are actively interacting with other accounts
df_prospective_users = (df_active
                        .loc[(df['productsSold'] == 0) & (df['productsBought'] == 0)]
                        .assign(user_type='prospective_user'))
df_prospective_users.describe()

# The descibe function provides us with key information concerning this segment:
# 15395 active users are prospective users: they haven't bought and sold anything yet but have either products listed for sell or have actively interacted with other accounts.
# Out:
#        identifierHash  socialNbFollowers  socialNbFollows  \
# count    1.539500e+04       15395.000000     15395.000000
# mean     4.773451e+16           3.538097         8.259760
# std      5.341006e+18           1.944908         1.371024
# min     -9.223101e+18           3.000000         0.000000
# 25%     -4.543043e+18           3.000000         8.000000
# 50%      7.042313e+16           3.000000         8.000000
# 75%      4.691885e+18           3.000000         8.000000
# max      9.223331e+18          36.000000        77.000000
#
#        socialProductsLiked  productsListed  productsSold  productsPassRate  \
# count         15395.000000    15395.000000       15395.0           15395.0
# mean              8.560247        0.057616           0.0               0.0
# std              39.732231        0.478313           0.0               0.0
# min               0.000000        0.000000           0.0               0.0
# 25%               1.000000        0.000000           0.0               0.0
# 50%               1.000000        0.000000           0.0               0.0
# 75%               5.000000        0.000000           0.0               0.0
# max            1590.000000       25.000000           0.0               0.0
#
#        productsWished  productsBought  civilityGenderId  daysSinceLastLogin  \
# count    15395.000000         15395.0      15395.000000        15395.000000
# mean         2.799545             0.0          1.842027          439.331601
# std         17.826188             0.0          0.386182          258.107789
# min          0.000000             0.0          1.000000           11.000000
# 25%          0.000000             0.0          2.000000          191.000000
# 50%          0.000000             0.0          2.000000          531.000000
# 75%          1.000000             0.0          2.000000          693.000000
# max       1225.000000             0.0          3.000000          709.000000
#
#           seniority  seniorityAsMonths  seniorityAsYears
# count  15395.000000       15395.000000      15395.000000
# mean    3061.660214         102.055186          8.504572
# std      168.745667           5.624636          0.469097
# min     2852.000000          95.070000          7.920000
# 25%     2857.000000          95.230000          7.940000
# 50%     3196.000000         106.530000          8.880000
# 75%     3201.000000         106.700000          8.890000
# max     3205.000000         106.830000          8.900000

# %%
# Reseting the dataframe for active users (now with a new column 'user_type')
user_segment = [df_exclusive_buyers, df_exclusive_sellers, df_buyers_sellers, df_prospective_users]
df_active = pd.concat(user_segment)
df_active.shape
# Out:
# (22288, 25)

# %%
df_active
# Out:
#             identifierHash  type      country language  socialNbFollowers  \
# 51    -6589093921826008799  user   Etats-Unis       en                  3
# 85     -937288556484695351  user        Suède       en                  5
# 95     7144186809315241123  user       Canada       en                  4
# 102    4994268169579335625  user  Royaume-Uni       en                  3
# 114    4907046938384800140  user   Etats-Unis       en                 28
# ...                    ...   ...          ...      ...                ...
# 98883  4686499517041021923  user   Etats-Unis       en                  7
# 98889  4508710134224075356  user       France       fr                  3
# 98896  4715935376764926056  user    Allemagne       en                  3
# 98901  7257878909040060228  user      Espagne       es                  3
# 98905  3164321379397826945  user   Etats-Unis       en                  3
#
#        socialNbFollows  socialProductsLiked  productsListed  productsSold  \
# 51                   9                    1               0             0
# 85                   8                    0               0             0
# 95                  10                    1               0             0
# 102                  8                    0               0             0
# 114                 29                    0               0             0
# ...                ...                  ...             ...           ...
# 98883                9                    0               0             0
# 98889                8                    1               0             0
# 98896                8                   10               0             0
# 98901                8                   31               0             0
# 98905                8                    6               0             0
#
#        productsPassRate  ...  hasAnyApp  hasAndroidApp hasIosApp  \
# 51                  0.0  ...      False          False     False
# 85                  0.0  ...      False          False     False
# 95                  0.0  ...       True           True     False
# 102                 0.0  ...      False          False     False
# 114                 0.0  ...       True          False      True
# ...                 ...  ...        ...            ...       ...
# 98883               0.0  ...      False          False     False
# 98889               0.0  ...      False          False     False
# 98896               0.0  ...       True          False      True
# 98901               0.0  ...      False          False     False
# 98905               0.0  ...      False          False     False
#
#        hasProfilePicture daysSinceLastLogin  seniority  seniorityAsMonths  \
# 51                  True                 26       3205             106.83
# 85                  True                543       3205             106.83
# 95                  True                208       3205             106.83
# 102                 True                 27       3205             106.83
# 114                False                 15       3205             106.83
# ...                  ...                ...        ...                ...
# 98883               True                708       3204             106.80
# 98889               True                477       3204             106.80
# 98896               True                 15       3204             106.80
# 98901               True                 13       3204             106.80
# 98905               True                655       3204             106.80
#
#        seniorityAsYears  countryCode         user_type
# 51                  8.9           us   exclusive_buyer
# 85                  8.9           se   exclusive_buyer
# 95                  8.9           ca   exclusive_buyer
# 102                 8.9           gb   exclusive_buyer
# 114                 8.9           us   exclusive_buyer
# ...                 ...          ...               ...
# 98883               8.9           us  prospective_user
# 98889               8.9           fr  prospective_user
# 98896               8.9           de  prospective_user
# 98901               8.9           es  prospective_user
# 98905               8.9           us  prospective_user
#
# [22288 rows x 25 columns]

# %%
df_active = df_active.assign(OS=np.where((df_active["hasAndroidApp"]&df_active["hasIosApp"]==True),"Both Apps",(np.where((df_active["hasAndroidApp"]==True),"Android",(np.where((df_active["hasIosApp"]==True),"iOS","Browser"))))))

# %%
df_active = df_active.assign(ratioBuySell=df_active["productsBought"]/df_active["productsSold"])

# %%
df_active.to_csv("df_active.csv")
