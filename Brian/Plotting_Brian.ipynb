# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_active = pd.read_csv("../Julien/df_active.csv")

# %%
df_active
# Out:
#        Unnamed: 0       identifierHash  type      country language  \
# 0              51 -6589093921826008799  user   Etats-Unis       en
# 1              85  -937288556484695351  user        Suède       en
# 2              95  7144186809315241123  user       Canada       en
# 3             102  4994268169579335625  user  Royaume-Uni       en
# 4             114  4907046938384800140  user   Etats-Unis       en
# ...           ...                  ...   ...          ...      ...
# 22283       98883  4686499517041021923  user   Etats-Unis       en
# 22284       98889  4508710134224075356  user       France       fr
# 22285       98896  4715935376764926056  user    Allemagne       en
# 22286       98901  7257878909040060228  user      Espagne       es
# 22287       98905  3164321379397826945  user   Etats-Unis       en
#
#        socialNbFollowers  socialNbFollows  socialProductsLiked  \
# 0                      3                9                    1
# 1                      5                8                    0
# 2                      4               10                    1
# 3                      3                8                    0
# 4                     28               29                    0
# ...                  ...              ...                  ...
# 22283                  7                9                    0
# 22284                  3                8                    1
# 22285                  3                8                   10
# 22286                  3                8                   31
# 22287                  3                8                    6
#
#        productsListed  productsSold  ...  hasIosApp  hasProfilePicture  \
# 0                   0             0  ...      False               True
# 1                   0             0  ...      False               True
# 2                   0             0  ...      False               True
# 3                   0             0  ...      False               True
# 4                   0             0  ...       True              False
# ...               ...           ...  ...        ...                ...
# 22283               0             0  ...      False               True
# 22284               0             0  ...      False               True
# 22285               0             0  ...       True               True
# 22286               0             0  ...      False               True
# 22287               0             0  ...      False               True
#
#        daysSinceLastLogin seniority  seniorityAsMonths seniorityAsYears  \
# 0                      26      3205             106.83              8.9
# 1                     543      3205             106.83              8.9
# 2                     208      3205             106.83              8.9
# 3                      27      3205             106.83              8.9
# 4                      15      3205             106.83              8.9
# ...                   ...       ...                ...              ...
# 22283                 708      3204             106.80              8.9
# 22284                 477      3204             106.80              8.9
# 22285                  15      3204             106.80              8.9
# 22286                  13      3204             106.80              8.9
# 22287                 655      3204             106.80              8.9
#
#        countryCode         user_type       OS  ratioBuySell
# 0               us   exclusive_buyer  Browser           inf
# 1               se   exclusive_buyer  Browser           inf
# 2               ca   exclusive_buyer  Android           inf
# 3               gb   exclusive_buyer  Browser           inf
# 4               us   exclusive_buyer      iOS           inf
# ...            ...               ...      ...           ...
# 22283           us  prospective_user  Browser           NaN
# 22284           fr  prospective_user  Browser           NaN
# 22285           de  prospective_user      iOS           NaN
# 22286           es  prospective_user  Browser           NaN
# 22287           us  prospective_user  Browser           NaN
#
# [22288 rows x 28 columns]

# %%
# Creating DF only with buyers and sellers
df_buyers = df_active.loc[((df_active["productsBought"]>=1))&(df_active["OS"]!="Both Apps")]
df_buyers
# Out:
#       Unnamed: 0       identifierHash  type      country language  \
# 0             51 -6589093921826008799  user   Etats-Unis       en
# 1             85  -937288556484695351  user        Suède       en
# 2             95  7144186809315241123  user       Canada       en
# 3            102  4994268169579335625  user  Royaume-Uni       en
# 4            114  4907046938384800140  user   Etats-Unis       en
# ...          ...                  ...   ...          ...      ...
# 6888       98260 -5414959342816599813  user     Pays-Bas       en
# 6889       98352 -1780456174896106635  user      Espagne       en
# 6890       98368  1844013789737284769  user     Portugal       en
# 6891       98442  3179447064315962304  user        Grèce       en
# 6892       98664 -2101187138099590218  user       France       fr
#
#       socialNbFollowers  socialNbFollows  socialProductsLiked  productsListed  \
# 0                     3                9                    1               0
# 1                     5                8                    0               0
# 2                     4               10                    1               0
# 3                     3                8                    0               0
# 4                    28               29                    0               0
# ...                 ...              ...                  ...             ...
# 6888                  8                9                   29              25
# 6889                 11                8                    9               0
# 6890                 31               10                  521               3
# 6891                 31                7                   14               3
# 6892                  3                8                    3               0
#
#       productsSold  ...  hasIosApp  hasProfilePicture  daysSinceLastLogin  \
# 0                0  ...      False               True                  26
# 1                0  ...      False               True                 543
# 2                0  ...      False               True                 208
# 3                0  ...      False               True                  27
# 4                0  ...       True              False                  15
# ...            ...  ...        ...                ...                 ...
# 6888            20  ...      False              False                  14
# 6889             2  ...      False               True                  26
# 6890             2  ...      False              False                  11
# 6891             1  ...       True              False                  17
# 6892             1  ...       True               True                 191
#
#      seniority  seniorityAsMonths seniorityAsYears  countryCode  \
# 0         3205             106.83              8.9           us
# 1         3205             106.83              8.9           se
# 2         3205             106.83              8.9           ca
# 3         3205             106.83              8.9           gb
# 4         3205             106.83              8.9           us
# ...        ...                ...              ...          ...
# 6888      3204             106.80              8.9           nl
# 6889      3204             106.80              8.9           es
# 6890      3204             106.80              8.9           pt
# 6891      3204             106.80              8.9           gr
# 6892      3204             106.80              8.9           fr
#
#              user_type       OS  ratioBuySell
# 0      exclusive_buyer  Browser           inf
# 1      exclusive_buyer  Browser           inf
# 2      exclusive_buyer  Android           inf
# 3      exclusive_buyer  Browser           inf
# 4      exclusive_buyer      iOS           inf
# ...                ...      ...           ...
# 6888  buyer_and_seller  Browser          0.05
# 6889  buyer_and_seller  Browser          0.50
# 6890  buyer_and_seller  Browser          8.50
# 6891  buyer_and_seller      iOS          1.00
# 6892  buyer_and_seller      iOS          2.00
#
# [5367 rows x 28 columns]

# %%
df_sellers = df_active.loc[((df_active["productsSold"]>=1))&(df_active["OS"]!="Both Apps")]
df_sellers
# Out:
#       Unnamed: 0       identifierHash  type      country language  \
# 4857         133 -4975676516338518373  user       France       fr
# 4858         164 -5922910413286749505  user  Royaume-Uni       en
# 4859         242  2070806682096194894  user       France       fr
# 4860         614  1675020017057075308  user     Finlande       en
# 4861        1084 -5427472487749231410  user    Allemagne       en
# ...          ...                  ...   ...          ...      ...
# 6888       98260 -5414959342816599813  user     Pays-Bas       en
# 6889       98352 -1780456174896106635  user      Espagne       en
# 6890       98368  1844013789737284769  user     Portugal       en
# 6891       98442  3179447064315962304  user        Grèce       en
# 6892       98664 -2101187138099590218  user       France       fr
#
#       socialNbFollowers  socialNbFollows  socialProductsLiked  productsListed  \
# 4857                  7                8                    6               1
# 4858                 10                8                    0               0
# 4859                  3                8                    0               0
# 4860                  8                8                    0               4
# 4861                  5                8                    1               0
# ...                 ...              ...                  ...             ...
# 6888                  8                9                   29              25
# 6889                 11                8                    9               0
# 6890                 31               10                  521               3
# 6891                 31                7                   14               3
# 6892                  3                8                    3               0
#
#       productsSold  ...  hasIosApp  hasProfilePicture  daysSinceLastLogin  \
# 4857             1  ...       True               True                 485
# 4858             3  ...       True               True                 665
# 4859             1  ...      False               True                 405
# 4860             3  ...       True               True                  82
# 4861             2  ...       True               True                 192
# ...            ...  ...        ...                ...                 ...
# 6888            20  ...      False              False                  14
# 6889             2  ...      False               True                  26
# 6890             2  ...      False              False                  11
# 6891             1  ...       True              False                  17
# 6892             1  ...       True               True                 191
#
#      seniority  seniorityAsMonths seniorityAsYears  countryCode  \
# 4857      3205             106.83              8.9           fr
# 4858      3205             106.83              8.9           gb
# 4859      3205             106.83              8.9           fr
# 4860      3205             106.83              8.9           fi
# 4861      3204             106.80              8.9           de
# ...        ...                ...              ...          ...
# 6888      3204             106.80              8.9           nl
# 6889      3204             106.80              8.9           es
# 6890      3204             106.80              8.9           pt
# 6891      3204             106.80              8.9           gr
# 6892      3204             106.80              8.9           fr
#
#              user_type       OS  ratioBuySell
# 4857  exclusive_seller      iOS          0.00
# 4858  exclusive_seller      iOS          0.00
# 4859  exclusive_seller  Browser          0.00
# 4860  exclusive_seller      iOS          0.00
# 4861  exclusive_seller      iOS          0.00
# ...                ...      ...           ...
# 6888  buyer_and_seller  Browser          0.05
# 6889  buyer_and_seller  Browser          0.50
# 6890  buyer_and_seller  Browser          8.50
# 6891  buyer_and_seller      iOS          1.00
# 6892  buyer_and_seller      iOS          2.00
#
# [2008 rows x 28 columns]

# %%
# Creating Group by User Type and OS, Count of Users
df_user_types_os = (df_active.groupby(["user_type","OS"]).agg({"identifierHash":"count"}).drop(index="Both Apps", level=1).sort_values(["OS","identifierHash"], ascending=False).reset_index())
df_user_types_os
# Out:
#            user_type       OS  identifierHash
# 0   prospective_user      iOS            6039
# 1    exclusive_buyer      iOS            1527
# 2   exclusive_seller      iOS             763
# 3   buyer_and_seller      iOS             309
# 4   prospective_user  Browser            8326
# 5    exclusive_buyer  Browser            2973
# 6   exclusive_seller  Browser             556
# 7   buyer_and_seller  Browser             192
# 8   prospective_user  Android             966
# 9    exclusive_buyer  Android             315
# 10  exclusive_seller  Android             137
# 11  buyer_and_seller  Android              51

# %%
# Creating Group by User Type, Count of Users
df_user_types = (df_active.groupby("user_type").agg({"identifierHash":"count"}).sort_values(["identifierHash"], ascending=False).reset_index())
df_user_types
# Out:
#           user_type  identifierHash
# 0  prospective_user           15395
# 1   exclusive_buyer            4857
# 2  exclusive_seller            1474
# 3  buyer_and_seller             562

# %%
# Creating Group of Users by OS
df_os = (df_active.groupby("OS").agg({"identifierHash":"count"}).sort_values(["identifierHash"], ascending=False).reset_index())
df_os
# Out:
#           OS  identifierHash
# 0    Browser           12047
# 1        iOS            8638
# 2    Android            1469
# 3  Both Apps             134

# %%
# Plotting User Segments and User Amounts
fig, ax = plt.subplots(figsize=(6,6))

sns.barplot(data=df_user_types,x="user_type",y="identifierHash", ax=ax);
sns.set(style="whitegrid");
ax.set(xlabel='User Segment', ylabel='Users');
plt.xticks(np.arange(4), ('Prospective Users', 'Exclusive Buyers', 'Exclusive Sellers','Buyer and Sellers'), rotation=45, 
    horizontalalignment='right',
    fontweight='light');

# %%
#Plotting User Segments/Amounts per OS
fig, ax = plt.subplots(figsize=(6,6))

sns.barplot(data=df_user_types_os,x="user_type",y="identifierHash",hue="OS", ax=ax);
sns.set(style="whitegrid");
ax.set(xlabel='User Segment', ylabel='Users');
plt.xticks(np.arange(4), ('Prospective Users', 'Exclusive Buyers', 'Exclusive Sellers','Buyer and Sellers'), rotation=45, 
    horizontalalignment='right',
    fontweight='light');

# %%
# Bar Chart for Operating System Distribution
fig, ax = plt.subplots(figsize=(6,6))

sns.barplot(data=df_os,x="OS",y="identifierHash", ax=ax);
sns.set(style="white");
ax.set(xlabel='Operating System', ylabel='Users');

# %%
# Creating DF for OS and descriptives for each relevant user group
df_avg_buy_type = (df_active.groupby(["OS","user_type"]).agg({"productsBought":["count","sum","median","mean"],"productsSold":["count","sum","median","mean"]}).drop(index="Both Apps").drop(index="prospective_user",level=1).sort_values(["user_type"], ascending=False).reset_index())
df_avg_buy_type
# Out:
#         OS         user_type productsBought                          \
#                                       count   sum median       mean
# 0  Android  exclusive_seller            137     0    0.0   0.000000
# 1  Browser  exclusive_seller            556     0    0.0   0.000000
# 2      iOS  exclusive_seller            763     0    0.0   0.000000
# 3  Android   exclusive_buyer            315   800    1.0   2.539683
# 4  Browser   exclusive_buyer           2973  6109    1.0   2.054827
# 5      iOS   exclusive_buyer           1527  4918    1.0   3.220694
# 6  Android  buyer_and_seller             51   581    4.0  11.392157
# 7  Browser  buyer_and_seller            192  1848    2.0   9.625000
# 8      iOS  buyer_and_seller            309  2353    2.0   7.614887
#
#   productsSold
#          count   sum median      mean
# 0          137   751      2  5.481752
# 1          556  2442      1  4.392086
# 2          763  4845      2  6.349934
# 3          315     0      0  0.000000
# 4         2973     0      0  0.000000
# 5         1527     0      0  0.000000
# 6           51   316      2  6.196078
# 7          192   791      1  4.119792
# 8          309  2650      2  8.576052

# %%
(df_active.groupby(["OS"]).agg({"productsBought":["count","sum","median","mean"],"productsSold":["count","sum","median","mean"]}).drop(index="Both Apps").reset_index())
# Out:
#         OS productsBought                        productsSold               \
#                     count   sum median      mean        count   sum median
# 0  Android           1469  1381      0  0.940095         1469  1067      0
# 1  Browser          12047  7957      0  0.660496        12047  3233      0
# 2      iOS           8638  7271      0  0.841746         8638  7495      0
#
#
#        mean
# 0  0.726344
# 1  0.268366
# 2  0.867678

# %%
# Making the DF for Buyers-Means Seaborn ready - no multilevel DF
df_avg_buy_type_sns = (df_active.groupby(["OS","user_type"]).agg({"productsBought":"mean"}).drop(index="Both Apps").drop(index=["prospective_user","exclusive_seller"],level=1).sort_values(["user_type"], ascending=False).reset_index())
df_avg_buy_type_sns
# Out:
#         OS         user_type  productsBought
# 0  Android   exclusive_buyer        2.539683
# 1  Browser   exclusive_buyer        2.054827
# 2      iOS   exclusive_buyer        3.220694
# 3  Android  buyer_and_seller       11.392157
# 4  Browser  buyer_and_seller        9.625000
# 5      iOS  buyer_and_seller        7.614887

# %%
# Making the DF for Seller-Means Seaborn ready - no multilevel DF
df_avg_sell_type_sns = (df_active.groupby(["OS","user_type"]).agg({"productsSold":"mean"}).drop(index="Both Apps").drop(index=["prospective_user","exclusive_buyer"],level=1).sort_values(["user_type"], ascending=False).reset_index())
df_avg_sell_type_sns
# Out:
#         OS         user_type  productsSold
# 0  Android  exclusive_seller      5.481752
# 1  Browser  exclusive_seller      4.392086
# 2      iOS  exclusive_seller      6.349934
# 3  Android  buyer_and_seller      6.196078
# 4  Browser  buyer_and_seller      4.119792
# 5      iOS  buyer_and_seller      8.576052

# %%
# Plotting Buyer OS Means
fig, ax = plt.subplots(figsize=(6,6))

sns.barplot(data=df_avg_buy_type_sns,x="user_type",y="productsBought",hue="OS", ax=ax);
sns.set(style="whitegrid");
ax.set(xlabel='User Segment', ylabel='Avg. Products Bought');

# %%
# Plotting Seller OS Means
fig, ax = plt.subplots(figsize=(6,6))

sns.barplot(data=df_avg_sell_type_sns,x="user_type",y="productsSold",hue="OS", ax=ax);
sns.set(style="whitegrid");
ax.set(xlabel='User Segment', ylabel='Avg. Products Sold');

# %%
# Making the DF only for buyers
df_avg_buyers = (df_buyers.groupby(["OS"]).agg({"productsBought":"mean"}).sort_values(["productsBought"], ascending=False).reset_index())
df_avg_buyers
# Out:
#         OS  productsBought
# 0      iOS        3.960240
# 1  Android        3.773224
# 2  Browser        2.514060

# %%
# Making the DF only for Sellers
df_avg_sellers = (df_sellers.groupby(["OS"]).agg({"productsSold":"mean"}).sort_values(["productsSold"], ascending=False).reset_index())
df_avg_sellers
# Out:
#         OS  productsSold
# 0      iOS      6.991604
# 1  Android      5.675532
# 2  Browser      4.322193

# %%
# Plotting Only-Buyers OS Means with CI
fig, ax = plt.subplots(figsize=(6,6))
sns.set_color_codes("muted")
palette={"Android":"g","Browser":"y","iOS":"b"}
sns.set(style="white")

sns.barplot(data=df_buyers,x="OS",y="productsBought", ax=ax, palette=palette);
ax.set(xlabel='User Segment', ylabel='Avg. Products Bought');

# %%
# Plotting Only-Buyers OS Means
fig, ax = plt.subplots(figsize=(6,6))
sns.set_color_codes("muted")
palette={"Android":"g","Browser":"y","iOS":"b"}
sns.set(style="white")

sns.barplot(data=df_avg_buyers,x="OS",y="productsBought", ax=ax, palette=palette);
ax.set(xlabel='User Segment', ylabel='Avg. Bought');

# %%
# Plotting Only-Sellers OS Means with CI
fig, ax = plt.subplots(figsize=(6,6))
sns.set_color_codes("muted")
palette={"Android":"g","Browser":"y","iOS":"b"}
sns.barplot(data=df_sellers,x="OS",y="productsSold", ax=ax,palette=palette);
sns.set(style="whitegrid");
ax.set(xlabel='User Segment', ylabel='Avg. Products Bought');

# %%
# Plotting Only-Buyers OS Means without CI
fig, ax = plt.subplots(figsize=(6,6))
sns.set_color_codes("muted")
palette={"Android":"g","Browser":"y","iOS":"b"}
sns.set(style="white")

sns.barplot(data=df_avg_sellers,x="OS",y="productsSold", ax=ax, palette=palette);
ax.set(xlabel='User Segment', ylabel='Avg. Sold');
